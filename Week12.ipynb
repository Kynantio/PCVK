# %% [markdown]
# <a href="https://colab.research.google.com/github/Kynantio/PCVK/blob/main/Week12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Jobsheet 12 PCVK
# # Kynantio Candra Abrari
# ## 2141720206 / 16 / 3A

# %%
import cv2 as cv
import cv2
from google.colab.patches import cv2_imshow
import numpy as np
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from PIL import Image

# %% [markdown]
# 1. Percobaan Face Detection

# %%
cascade_wajah = cv.CascadeClassifier('/content/drive/MyDrive/Polinema/PCVK/Images/Week12/haarcascade_frontalface_alt.xml')

jokowi = cv.imread('/content/drive/MyDrive/Polinema/PCVK/Images/Week12/jokowi.jpg',0)
roi_wajah = cascade_wajah.detectMultiScale(jokowi)
for(x,y,w,h) in roi_wajah:
  cv.rectangle(jokowi,(x,y),(x+w,y+h),(255,255,255),3)
plt.figure(figsize = (5,5))
plt.imshow(jokowi, cmap='gray')

# %% [markdown]
# ### Membuat Fungsi untuk Memudahkan Konversi Warna Citra

# %%
def bgr_to_rgb(images):
  return cv2.cvtColor(images, cv2.COLOR_BGR2RGB)

def gray_to_rgb(images):
  return cv2.cvtColor(images, cv2.COLOR_GRAY2RGB)

def bgr_to_gray(images):
  return cv2.cvtColor(images, cv2.COLOR_BGR2GRAY)

# %% [markdown]
# 2. Face detection untuk beberapa citra

# %%
# Mendefinisikan Cascade Classifier
cascade_wajah = cv2.CascadeClassifier('/content/drive/MyDrive/Polinema/PCVK/Images/Week12/haarcascade_frontalface_alt.xml')

# Jokowi

jokowi_bgr = cv2.imread('/content/drive/MyDrive/Polinema/PCVK/Images/Week12/jokowi.jpg')
jokowi = cv2.imread('/content/drive/MyDrive/Polinema/PCVK/Images/Week12/jokowi.jpg')

# Mendeteksi wajah
roi_wajah = cascade_wajah.detectMultiScale(jokowi_bgr)

# Menggambar kotak hijau di sekitar wajah pada gambar BGR
for (x, y, w, h) in roi_wajah:
    cv2.rectangle(jokowi_bgr, (x, y), (x+w, y+h), (0, 255, 0), 3)

# Mengonversi gambar BGR ke RGB menggunakan fungsi bgr_to_rgb
jokowi_rgb = bgr_to_rgb(jokowi_bgr)

# Menampilkan gambar dengan kotak hijau di sekitar wajah
plt.figure(figsize=(8, 8))
plt.subplot(121), plt.imshow(bgr_to_rgb(jokowi))
plt.axis('off')
plt.subplot(122), plt.imshow(jokowi_rgb)
plt.axis('off')
plt.show()


# RA. Kartini

kartini_bgr = cv2.imread('/content/drive/MyDrive/Polinema/PCVK/Images/Week12/kartini.jpg')
kartini = cv2.imread('/content/drive/MyDrive/Polinema/PCVK/Images/Week12/kartini.jpg')

# Mendeteksi wajah
roi_wajah = cascade_wajah.detectMultiScale(kartini_bgr)

# Menggambar kotak hijau di sekitar wajah pada gambar BGR
for (x, y, w, h) in roi_wajah:
    cv2.rectangle(kartini_bgr, (x, y), (x+w, y+h), (0, 255, 0), 3)

# Mengonversi gambar BGR ke RGB menggunakan fungsi bgr_to_rgb
kartini_rgb = bgr_to_rgb(kartini_bgr)

# Menampilkan gambar dengan kotak hijau di sekitar wajah
plt.figure(figsize=(8, 8))
plt.subplot(121), plt.imshow(bgr_to_rgb(kartini))
plt.axis('off')
plt.subplot(122), plt.imshow(kartini_rgb)
plt.axis('off')
plt.show()

# Perempuan bermasker

mask_gray = cv2.imread('/content/drive/MyDrive/Polinema/PCVK/Images/Week12/mask.png',0)

# Mendeteksi wajah
roi_wajah = cascade_wajah.detectMultiScale(mask_gray)

# Mengonversi gambar grayscale ke RGB untuk menyimpan warna hijau
mask_gray_rgb = gray_to_rgb(mask_gray)

# Menggambar kotak hijau di sekitar wajah pada gambar BGR
for (x, y, w, h) in roi_wajah:
    cv2.rectangle(mask_gray_rgb, (x, y), (x+w, y+h), (0, 255, 0), 3)

# Menampilkan gambar dengan kotak hijau di sekitar wajah
plt.figure(figsize=(8, 8))
plt.subplot(121), plt.imshow(mask_gray, cmap='gray')
plt.axis('off')
plt.subplot(122), plt.imshow(mask_gray_rgb)
plt.axis('off')
plt.show()

# Jordan

jordan_gray = cv2.imread('/content/drive/MyDrive/Polinema/PCVK/Images/Week12/mjordan.jpg',0)

# Mendeteksi wajah
roi_wajah = cascade_wajah.detectMultiScale(jordan_gray)

# Mengonversi gambar grayscale ke RGB untuk menyimpan warna hijau
jordan_gray_rgb = gray_to_rgb(jordan_gray)

# Menggambar kotak hijau di sekitar wajah pada gambar BGR
for (x, y, w, h) in roi_wajah:
    cv2.rectangle(jordan_gray_rgb, (x, y), (x+w, y+h), (0, 255, 0), 3)

# Menampilkan gambar dengan kotak hijau di sekitar wajah
plt.figure(figsize=(8, 8))
plt.subplot(121), plt.imshow(jordan_gray, cmap='gray')
plt.axis('off')
plt.subplot(122), plt.imshow(jordan_gray_rgb)
plt.axis('off')
plt.show()

# Solvayconf

solvay_gray = cv2.imread('/content/drive/MyDrive/Polinema/PCVK/Images/Week12/solvayconf.jpg', 0)

# Mendeteksi wajah
roi_wajah = cascade_wajah.detectMultiScale(solvay_gray)

# Mengonversi gambar grayscale ke RGB untuk menyimpan warna hijau
solvay_gray_rgb = gray_to_rgb(solvay_gray)

# Menggambar kotak hijau di sekitar wajah pada gambar grayscale
for (x, y, w, h) in roi_wajah:
    cv2.rectangle(solvay_gray_rgb, (x, y), (x+w, y+h), (0, 255, 0), 3)

# Menampilkan kedua gambar
plt.figure(figsize=(8, 8))

plt.subplot(121), plt.imshow(solvay_gray, cmap='gray')
plt.axis('off')

plt.subplot(122), plt.imshow(solvay_gray_rgb)
plt.axis('off')

plt.show()

# %% [markdown]
# ### 3. Face Detection - Kucing
# Pada Soal No.2. wajah kucing tidak bisa dideteksi dengan baik. Lakukan deteksi wajah kucing hingga muncul rectangle pada bagian wajahnya. Petunjuk pada soal ini, perhatikan pretrained features yang telah disediakan OpenCV. Gunakan xml yang adajika memang telah disediakan. Jika belum ada, coba cari dengan searching melalui search engines.

# %%
# Mendefinisikan Cascade Classifier
cascade_wajah = cv2.CascadeClassifier('/content/drive/MyDrive/Polinema/PCVK/Images/Week12/haarcascade_frontalcatface.xml')

# Membaca gambar kucing
kucing_bgr = cv2.imread('/content/drive/MyDrive/Polinema/PCVK/Images/Week12/mycat.jpg')

# Mendeteksi wajah dengan penyesuaian parameter
roi_wajah = cascade_wajah.detectMultiScale(kucing_bgr)

# Menggambar kotak hijau di sekitar wajah pada gambar BGR
for (x, y, w, h) in roi_wajah:
    cv2.rectangle(kucing_bgr, (x, y), (x+w, y+h), (0, 255, 0), 3)

# Mengonversi gambar BGR ke RGB untuk ditampilkan
kucing_rgb = cv2.cvtColor(kucing_bgr, cv2.COLOR_BGR2RGB)

# Menampilkan gambar dengan kotak hijau di sekitar wajah
plt.figure(figsize=(8, 8))
plt.subplot(121), plt.imshow(kucing_rgb)
plt.axis('off')
plt.show()

# %% [markdown]
# ### 4. Eyes Detection

# %%
# Jokowi

# Mendefinisikan Cascade Classifier
cascade_wajah = cv2.CascadeClassifier('/content/drive/MyDrive/Polinema/PCVK/Images/Week12/haarcascade_eye.xml')

jokowi_bgr = cv2.imread('/content/drive/MyDrive/Polinema/PCVK/Images/Week12/jokowi.jpg',0)
jokowi_gray = cv2.imread('/content/drive/MyDrive/Polinema/PCVK/Images/Week12/jokowi.jpg',0)

roi_wajah = cascade_wajah.detectMultiScale(jokowi_gray)

for(x,y,w,h) in roi_wajah:
  cv.rectangle(jokowi_gray,(x,y),(x+w,y+h),(255,255,255),3)

# Menampilkan gambar dengan kotak hijau di sekitar wajah
plt.figure(figsize=(8, 8))
plt.subplot(121), plt.imshow(jokowi_bgr, cmap='gray')
plt.axis('off')
plt.subplot(122), plt.imshow(jokowi_gray, cmap='gray')
plt.axis('off')
plt.show()

# %% [markdown]
# ### 5. Face Tracking
# Pada percobaan kali ini akan mengakses kamera dan FaceDetection pada google colab

# %%
## Mohon Maaf Laptop Saya Tidak Memiliki Kamera

# %% [markdown]
# ### 6.Blurring pada Face Detection

# %%
jordan = cv2.imread('/content/drive/MyDrive/Polinema/PCVK/Images/Week12/mjordan.jpg',0)

# Load the pre-trained face detector
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

# Detect faces in the image
faces = face_cascade.detectMultiScale(jordan, scaleFactor=1.1, minNeighbors=5, minSize=(30, 30))

# Apply blurring to the detected faces
for (x, y, w, h) in faces:
    face_roi = jordan[y:y+h, x:x+w]
    blurred_face = cv2.medianBlur(face_roi, 15)
    jordan[y:y+h, x:x+w] = blurred_face

# Display the image with blurring applied to the faces
plt.figure(figsize=(8, 8))
plt.imshow(jordan, cmap='gray')
plt.axis('on')
plt.show()

# %% [markdown]
# ### 7. Segmentasi Karakter pada KTP

# %%
from google.colab.patches import cv2_imshow
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt

# Baca gambar
ktp = cv.imread("/content/drive/MyDrive/Polinema/PCVK/Images/Week12/dataset_ktp/ktp3.png")

# Filtering dengan Gaussian Blur
blurred = cv.GaussianBlur(ktp, (5, 5), 0)

# Ubah ke citra keabuan
gray = cv.cvtColor(blurred, cv.COLOR_BGR2GRAY)

# Binerisasi citra dengan Adaptive Thresholding
bw = cv.adaptiveThreshold(gray, 255, cv.ADAPTIVE_THRESH_GAUSSIAN_C, cv.THRESH_BINARY_INV, 11, 5)

# Ekstraksi kontur
contours, hierarchy = cv.findContours(bw.copy(), cv.RETR_TREE, cv.CHAIN_APPROX_SIMPLE)

# Gambar hasil biner
plt.figure(figsize=(15, 5))

# Looping contours untuk mendapatkan kontur yang sesuai
for cnt in contours:
    x, y, w, h = cv.boundingRect(cnt)
    ras = format(w / h, '.2f')
    if h >= 10 and w >= 5 and float(ras) <= 1:
        cv.rectangle(ktp, (x, y), (x + w, y + h), (0, 0, 255), thickness=1)

# Gambar hasil akhir
plt.imshow(cv.cvtColor(ktp, cv.COLOR_BGR2RGB))
plt.axis('off')
plt.show()

# %% [markdown]
# ### 8. Cropping NIK

# %%
cropped_nik = ktp[50:70, 110:330]

plt.imshow(cv.cvtColor(cropped_nik, cv.COLOR_BGR2RGB))
plt.axis('off')
plt.show()

# %% [markdown]
# ### 9. Pengenalan Karakter dengan Deep Learning

# %%
import os
import cv2
import numpy as np
import pickle
import tensorflow as tf
from keras.utils import to_categorical
from keras.layers import Input, Conv2D, MaxPooling2D, Flatten, Dense, ZeroPadding2D
from keras.models import Model
from keras.optimizers import Adam

# Load dataset MNIST
(X_train, y_train), (_, _) = tf.keras.datasets.mnist.load_data()

# Jumlah data yang ingin diambil dari setiap kategori
num_samples_per_class = 100

# List digit yang akan diambil (0 sampai 9)
digits_to_extract = list(range(10))

# Fungsi untuk mengambil sampel dari setiap kategori
def extract_samples(X, y, digits, num_samples):
    samples = []
    for digit in digits:
        digit_indices = np.where(y == digit)[0]
        selected_indices = np.random.choice(digit_indices, num_samples, replace=False)
        samples.extend([(X[i], digit) for i in selected_indices])
    return samples

# Ambil sampel dari setiap kategori
training_data = extract_samples(X_train, y_train, digits_to_extract, num_samples_per_class)

# Acak urutan data
np.random.shuffle(training_data)

# Pisahkan fitur dan label
X, Y = zip(*training_data)

# Konversi menjadi numpy array
X = np.array(X).reshape(-1, 28, 28, 1)

# Tulis ke file pickle
pickle_out = open("X_mnist.pickle", "wb")
pickle.dump(X, pickle_out)
pickle_out.close()

pickle_out = open("Y_mnist.pickle", "wb")
pickle.dump(to_categorical(Y, num_classes=10), pickle_out)
pickle_out.close()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 1s 0us/step

# %% [markdown]
# ### 10. Training Data

# %%
# Load file pickle
pickle_in = open("X_mnist.pickle", "rb")
X = pickle.load(pickle_in)
pickle_in = open("Y_mnist.pickle", "rb")
Y = pickle.load(pickle_in)

width, height = 28, 28  # Sesuaikan dengan ukuran gambar MNIST

# Input layer
inputs = Input(shape=(width, height, 1))
conv_layer = ZeroPadding2D(padding=(2, 2))(inputs)
conv_layer = Conv2D(16, (5, 5), strides=(1, 1), activation='relu')(conv_layer)
conv_layer = MaxPooling2D((2, 2))(conv_layer)
conv_layer = Conv2D(32, (3, 3), strides=(1, 1), activation='relu')(conv_layer)
conv_layer = Conv2D(32, (3, 3), strides=(1, 1), activation='relu')(conv_layer)
conv_layer = MaxPooling2D((2, 2))(conv_layer)
conv_layer = Conv2D(64, (3, 3), strides=(1, 1), activation='relu')(conv_layer)
flaten = Flatten()(conv_layer)
fc_layer = Dense(256, activation='relu')(flaten)
fc_layer = Dense(64, activation='relu')(fc_layer)

# Output layer
outputs = Dense(10, activation='softmax')(fc_layer)

adam = Adam(learning_rate=0.0001)
model = Model(inputs=inputs, outputs=outputs)
model.compile(optimizer=adam, loss='categorical_crossentropy', metrics=['accuracy'])
model.fit(X, Y, epochs=20, verbose=1)
model.save('anpr.model')
# Out:
# Epoch 1/20
# 32/32 [==============================] - 3s 33ms/step - loss: 4.2101 - accuracy: 0.2150
# Epoch 2/20
# 32/32 [==============================] - 1s 45ms/step - loss: 1.3844 - accuracy: 0.5570
# Epoch 3/20
# 32/32 [==============================] - 2s 63ms/step - loss: 0.7992 - accuracy: 0.7250
# Epoch 4/20
# 32/32 [==============================] - 2s 61ms/step - loss: 0.5117 - accuracy: 0.8360
# Epoch 5/20
# 32/32 [==============================] - 3s 85ms/step - loss: 0.3305 - accuracy: 0.8930
# Epoch 6/20
# 32/32 [==============================] - 3s 84ms/step - loss: 0.2458 - accuracy: 0.9340
# Epoch 7/20
# 32/32 [==============================] - 4s 114ms/step - loss: 0.1662 - accuracy: 0.9590
# Epoch 8/20
# 32/32 [==============================] - 2s 51ms/step - loss: 0.1108 - accuracy: 0.9860
# Epoch 9/20
# 32/32 [==============================] - 2s 60ms/step - loss: 0.0838 - accuracy: 0.9890
# Epoch 10/20
# 32/32 [==============================] - 2s 49ms/step - loss: 0.0595 - accuracy: 0.9960
# Epoch 11/20
# 32/32 [==============================] - 1s 30ms/step - loss: 0.0428 - accuracy: 0.9970
# Epoch 12/20
# 32/32 [==============================] - 1s 31ms/step - loss: 0.0329 - accuracy: 0.9990
# Epoch 13/20
# 32/32 [==============================] - 1s 32ms/step - loss: 0.0259 - accuracy: 1.0000
# Epoch 14/20
# 32/32 [==============================] - 1s 31ms/step - loss: 0.0213 - accuracy: 1.0000
# Epoch 15/20
# 32/32 [==============================] - 1s 36ms/step - loss: 0.0176 - accuracy: 1.0000
# Epoch 16/20
# 32/32 [==============================] - 2s 53ms/step - loss: 0.0150 - accuracy: 1.0000
# Epoch 17/20
# 32/32 [==============================] - 2s 50ms/step - loss: 0.0129 - accuracy: 1.0000
# Epoch 18/20
# 32/32 [==============================] - 2s 51ms/step - loss: 0.0109 - accuracy: 1.0000
# Epoch 19/20
# 32/32 [==============================] - 2s 53ms/step - loss: 0.0094 - accuracy: 1.0000
# Epoch 20/20
# 32/32 [==============================] - 2s 47ms/step - loss: 0.0085 - accuracy: 1.0000

# %% [markdown]
# ### 11. Testing Data

# %%
import os
import cv2
import numpy as np
import pickle
import tensorflow as tf
from keras.utils import to_categorical

# Load dataset MNIST yang sudah disiapkan sebelumnya
pickle_in = open("X_mnist.pickle", "rb")
X_test = pickle.load(pickle_in)
pickle_in = open("Y_mnist.pickle", "rb")
Y_test = pickle.load(pickle_in)

# Normalisasi data testing
X_test = X_test / 255.0

# Load model yang sudah di-training sebelumnya
model = tf.keras.models.load_model("anpr.model")

# Lakukan prediksi pada data testing
predictions = model.predict(X_test)

# Ubah label ke dalam format one-hot encoding
Y_test_one_hot = to_categorical(Y_test)

# Evaluasi performa model
accuracy = model.evaluate(X_test, Y_test)[1]
print("Accuracy on the test set: {:.2f}%".format(accuracy * 100))
# Out:
# 32/32 [==============================] - 0s 9ms/step
# 32/32 [==============================] - 1s 18ms/step - loss: 2.2551 - accuracy: 0.9980
# Accuracy on the test set: 99.80%

# %% [markdown]
# ### Pelabelan Citra Data Testing

# %%
import numpy as np
import matplotlib.pyplot as plt

# Fungsi untuk menampilkan gambar dan label
def show_images(images, true_labels, predicted_labels):
    plt.figure(figsize=(15, 6))
    for i in range(len(images)):
        plt.subplot(5, 10, i + 1)
        plt.imshow(images[i][:, :, 0], cmap='gray')

        # Tentukan warna teks berdasarkan prediksi yang benar atau salah
        text_color = 'red' if true_labels[i] != predicted_labels[i] else 'black'

        plt.title(f'True: {true_labels[i]}\nPred: {predicted_labels[i]}', color=text_color)
        plt.axis('off')
    plt.tight_layout()
    plt.show()

# Load dataset MNIST yang sudah disiapkan sebelumnya
pickle_in = open("X_mnist.pickle", "rb")
X_test = pickle.load(pickle_in)
pickle_in = open("Y_mnist.pickle", "rb")
Y_test = pickle.load(pickle_in)

# Normalisasi data testing
X_test = X_test / 255.0

# Load model yang sudah di-training sebelumnya
model = tf.keras.models.load_model("anpr.model")

# Lakukan prediksi pada data testing
predictions = model.predict(X_test)

# Ambil label yang benar (tanpa one-hot encoding)
true_labels = Y_test.argmax(axis=1)

# Ambil label prediksi (tanpa one-hot encoding)
predicted_labels = np.argmax(predictions, axis=1)

# Pilih 50 gambar secara acak untuk ditampilkan
num_samples_to_show = 50
sample_indices = np.random.choice(len(X_test), num_samples_to_show, replace=False)

# Tampilkan gambar dan labelnya
show_images(X_test[sample_indices], true_labels[sample_indices], predicted_labels[sample_indices])
# Out:
# 32/32 [==============================] - 1s 16ms/step

# %% [markdown]
# ## Tugas
# Silakan melakukan pengenalan NIK pada e-KTP yang terdapat pada tugas modul 11!

# %%
from google.colab.patches import cv2_imshow
import cv2 as cv
import numpy as np

ktp = cv.imread("/content/drive/MyDrive/Polinema/PCVK/Images/Week12/dataset_ktp/ktp6.png")

# Filtering
blurred = cv.GaussianBlur(ktp, (5, 5), 0.5)

# Binerisasi citra dengan Otsu's thresholding
gray = cv.cvtColor(blurred, cv.COLOR_BGR2GRAY)
ret, bw = cv.threshold(gray.copy(), 0, 255, cv.THRESH_BINARY + cv.THRESH_OTSU)

# Morfologi erosi
erode = cv.erode(bw.copy(), cv.getStructuringElement(cv.MORPH_OPEN, (1, 1)))

# Ekstraksi kontur
contours, hierarchy = cv.findContours(erode.copy(), cv.RETR_TREE, cv.CHAIN_APPROX_SIMPLE)

plt.figure(figsize=(15,5))
# Looping contours untuk mendapatkan kontur yang sesuai
for cnt in contours:
    x, y, w, h = cv.boundingRect(cnt)
    ras = format(w / h, '.2f')
    if h >= 10 and w >= 5 and float(ras) <= 1:
        cv.rectangle(ktp, (x, y), (x + w, y + h), (0, 0, 255), thickness=1)

# Gambar hasil akhir
plt.imshow(cv2.cvtColor(ktp, cv2.COLOR_BGR2RGB))
plt.axis('off')
# Out:
# (-0.5, 995.5, 635.5, -0.5)

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
from keras.utils import to_categorical

# Asumsi ukuran gambar 28x28 pixel
height, width, channels = 28, 28, 1

# Asumsi jumlah kelas (contoh: digit 0-9)
num_classes = 10

# Asumsi dataset MNIST (sesuaikan dengan dataset karakter yang Anda miliki)
(X_train, Y_train), (X_test, Y_test) = tf.keras.datasets.mnist.load_data()

# Praproses dataset
X_train = X_train.reshape(-1, height, width, channels).astype('float32') / 255.0
X_test = X_test.reshape(-1, height, width, channels).astype('float32') / 255.0
Y_train = to_categorical(Y_train, num_classes)
Y_test = to_categorical(Y_test, num_classes)

# Asumsi model (gunakan arsitektur yang sesuai dengan kebutuhan)
model = Sequential()
model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(height, width, channels)))
model.add(MaxPooling2D((2, 2)))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dense(num_classes, activation='softmax'))

# Kompilasi model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Latih model
model.fit(X_train, Y_train, epochs=10, batch_size=32, validation_split=0.2)

# Evaluasi model
accuracy = model.evaluate(X_test, Y_test)[1]
print(f"Accuracy on test set: {accuracy * 100:.2f}%")
# Out:
# Epoch 1/10
# 1500/1500 [==============================] - 50s 33ms/step - loss: 0.1676 - accuracy: 0.9504 - val_loss: 0.0757 - val_accuracy: 0.9761
# Epoch 2/10
# 1500/1500 [==============================] - 38s 26ms/step - loss: 0.0565 - accuracy: 0.9824 - val_loss: 0.0647 - val_accuracy: 0.9811
# Epoch 3/10
# 1500/1500 [==============================] - 41s 28ms/step - loss: 0.0356 - accuracy: 0.9888 - val_loss: 0.0584 - val_accuracy: 0.9830
# Epoch 4/10
# 1500/1500 [==============================] - 40s 27ms/step - loss: 0.0234 - accuracy: 0.9926 - val_loss: 0.0554 - val_accuracy: 0.9839
# Epoch 5/10
# 1500/1500 [==============================] - 41s 27ms/step - loss: 0.0156 - accuracy: 0.9950 - val_loss: 0.0541 - val_accuracy: 0.9843
# Epoch 6/10
# 1500/1500 [==============================] - 40s 26ms/step - loss: 0.0106 - accuracy: 0.9965 - val_loss: 0.0549 - val_accuracy: 0.9854
# Epoch 7/10
# 1500/1500 [==============================] - 40s 27ms/step - loss: 0.0080 - accuracy: 0.9974 - val_loss: 0.0602 - val_accuracy: 0.9864
# Epoch 8/10
# 1500/1500 [==============================] - 41s 27ms/step - loss: 0.0067 - accuracy: 0.9979 - val_loss: 0.0571 - val_accuracy: 0.9872
# Epoch 9/10
# 1500/1500 [==============================] - 39s 26ms/step - loss: 0.0075 - accuracy: 0.9974 - val_loss: 0.0643 - val_accuracy: 0.9861
# Epoch 10/10
# 1500/1500 [==============================] - 40s 26ms/step - loss: 0.0031 - accuracy: 0.9990 - val_loss: 0.0693 - val_accuracy: 0.9848
# 313/313 [==============================] - 3s 9ms/step - loss: 0.0649 - accuracy: 0.9836
# Accuracy on test set: 98.36%

# %%
import numpy as np
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
from keras.utils import to_categorical
from sklearn.model_selection import train_test_split

# Asumsi ukuran gambar karakter NIK
height, width, channels = 28, 28, 1

# Asumsi jumlah kelas karakter (sesuaikan dengan karakter pada NIK)
num_classes = 36  # Misalnya, karakter 0-9 dan A-Z

# Asumsi dataset karakter NIK dari hasil segmentasi (ganti dengan dataset yang sesuai)
# Contoh: data_X dan data_Y adalah matriks gambar karakter dan labelnya
# Pastikan data_X dan data_Y dihasilkan dari hasil segmentasi karakter KTP yang telah dilakukan sebelumnya
# Misalnya, dapat berupa gambar karakter NIK dan labelnya.

# Membuat contoh data, Anda perlu mengganti ini dengan data aktual dari hasil segmentasi
data_X = np.random.rand(100, height, width, channels)
data_Y = np.random.randint(0, num_classes, size=(100,))

# Praproses dataset
data_X = data_X.astype('float32') / 255.0
data_Y = to_categorical(data_Y, num_classes)

# Bagi data menjadi data latih dan data uji
X_train, X_test, Y_train, Y_test = train_test_split(data_X, data_Y, test_size=0.2, random_state=42)

# Asumsi model (gunakan arsitektur yang sesuai dengan kebutuhan)
model = Sequential()
model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(height, width, channels)))
model.add(MaxPooling2D((2, 2)))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dense(num_classes, activation='softmax'))

# Kompilasi model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Latih model
model.fit(X_train, Y_train, epochs=10, batch_size=32, validation_split=0.2)

# Evaluasi model
accuracy = model.evaluate(X_test, Y_test)[1]
print(f"Accuracy on test set: {accuracy * 100:.2f}%")
# Out:
# Epoch 1/10
# 2/2 [==============================] - 1s 235ms/step - loss: 3.5834 - accuracy: 0.0469 - val_loss: 3.5785 - val_accuracy: 0.1250
# Epoch 2/10
# 2/2 [==============================] - 0s 73ms/step - loss: 3.5767 - accuracy: 0.0625 - val_loss: 3.5709 - val_accuracy: 0.1250
# Epoch 3/10
# 2/2 [==============================] - 0s 55ms/step - loss: 3.5644 - accuracy: 0.0625 - val_loss: 3.5575 - val_accuracy: 0.0000e+00
# Epoch 4/10
# 2/2 [==============================] - 0s 73ms/step - loss: 3.5446 - accuracy: 0.0469 - val_loss: 3.5387 - val_accuracy: 0.0000e+00
# Epoch 5/10
# 2/2 [==============================] - 0s 83ms/step - loss: 3.5122 - accuracy: 0.0469 - val_loss: 3.5167 - val_accuracy: 0.0000e+00
# Epoch 6/10
# 2/2 [==============================] - 0s 50ms/step - loss: 3.4778 - accuracy: 0.0469 - val_loss: 3.4948 - val_accuracy: 0.0000e+00
# Epoch 7/10
# 2/2 [==============================] - 0s 49ms/step - loss: 3.4328 - accuracy: 0.0469 - val_loss: 3.4762 - val_accuracy: 0.0000e+00
# Epoch 8/10
# 2/2 [==============================] - 0s 52ms/step - loss: 3.3906 - accuracy: 0.0781 - val_loss: 3.4738 - val_accuracy: 0.0000e+00
# Epoch 9/10
# 2/2 [==============================] - 0s 49ms/step - loss: 3.3661 - accuracy: 0.0781 - val_loss: 3.4857 - val_accuracy: 0.0000e+00
# Epoch 10/10
# 2/2 [==============================] - 0s 58ms/step - loss: 3.3442 - accuracy: 0.0781 - val_loss: 3.5063 - val_accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 29ms/step - loss: 3.9426 - accuracy: 0.0500
# Accuracy on test set: 5.00%
